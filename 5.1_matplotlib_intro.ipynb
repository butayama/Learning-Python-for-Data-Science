# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(0, np.pi*4, num=200)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %%
z = np.cos(x)

plt.plot(x,y,'r', label='sin(x)')
plt.plot(x,z, 'b', label = 'cos(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.xlim([0,6])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(x,z,'b')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x,y,label='sin(x)')
axes.legend()

axes.set_xlabel()
axes.set_title()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-21e2de46e1df> in <module>
#       6 axes.legend()
#       7
# ----> 8 axes.set_xlabel()
#       9 axes.set_title()
#      10
#
# TypeError: set_xlabel() missing 1 required positional argument: 'xlabel'
